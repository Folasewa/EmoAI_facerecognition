# %% [markdown]
# <a href="https://colab.research.google.com/github/Folasewa/EmoAI_facerecognition/blob/main/EmoAI_pose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 6.1 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 72.0 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
dataset = load_dataset('Datatang/Occluded_and_Multi-pose_Face_Recognition_Data')
# Out:
# ...
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to /root/.cache/huggingface/datasets/Datatang___imagefolder/Datatang--Occluded_and_Multi-pose_Face_Recognition_Data-3d10ba551186c914/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset['train'].info
# Out:
# DatasetInfo(description='', citation='', homepage='', license='', features={'image': Image(decode=True, id=None)}, post_processed=None, supervised_keys=None, task_templates=None, builder_name='imagefolder', config_name='Datatang--Occluded_and_Multi-pose_Face_Recognition_Data', version=0.0.0, splits={'train': SplitInfo(name='train', num_bytes=117, num_examples=1, shard_lengths=None, dataset_name='imagefolder')}, download_checksums={'https://huggingface.co/datasets/Datatang/Occluded_and_Multi-pose_Face_Recognition_Data/resolve/181effebe1094fa3ee23f9dbb5d255f4c2fe92a7/3.png': {'num_bytes': 3804525, 'checksum': None}}, download_size=3804525, post_processing_size=None, dataset_size=117, size_in_bytes=3804642)

# %%
dataset['train'].features
# Out:
# {'image': Image(decode=True, id=None)}

# %%
print(dataset['train'][0])
# Out:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1462x1036 at 0x7FB066F1D220>}

# %%
import matplotlib.pyplot as plt
image = dataset['train'][0]['image']

plt.imshow(image)
plt.show()
